# %%
import pandas as pd
import numpy as np

# %%
# Importing the HCAHPS Data
hcahps=pd.read_csv("HCAHPS-Hospital (1).csv")
hcahps.head()
# Out:
# C:\Users\hamid\AppData\Local\Temp\ipykernel_10592\2885563315.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   hcahps=pd.read_csv("HCAHPS-Hospital (1).csv")
#   Facility ID                    Facility Name                 Address  \
# 0       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4       10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name    Phone Number      HCAHPS Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701           H_COMP_1_A_P
# 1  DOTHAN    AL     36301     HOUSTON  (334) 793-8701          H_COMP_1_SN_P
# 2  DOTHAN    AL     36301     HOUSTON  (334) 793-8701           H_COMP_1_U_P
# ...

# %%
# import hospital info
hsp=pd.read_csv("HospitalData_Revised.csv")
hsp.head()
# Out:
#         County Code  Perm ID                           Facility Name  \
# 0  19 - Los Angeles    11758  Kaiser Foundation Hospital - South Bay
# 1       10 - Fresno    16116         Clovis Community Medical Center
# 2       10 - Fresno    16116         Clovis Community Medical Center
# 3       10 - Fresno    16116         Clovis Community Medical Center
# 4       10 - Fresno    16116         Clovis Community Medical Center
#
#           City Building Nbr                        Building Name  \
# 0  Harbor City    BLD-06482        Emergency Department Addition
# 1       Clovis    BLD-06051                      North Bed Tower
# 2       Clovis    BLD-06052                 Support Expansion 3A
# 3       Clovis    BLD-06053                 Support Expansion 3B
# 4       Clovis    BLD-06054  Diagnostic & Treatment Expansion 3A
#
#   Building Status SPC Rating *  \
# 0      In Service            5
# 1      In Service           5s
# 2      In Service           5s
# ...

# %%
# Selecting HCAHPS of California
hcahps_ca=hcahps[hcahps["State"]=="CA"]
hcahps_ca.head()
# Out:
#       Facility ID     Facility Name             Address     City State  \
# 25761       50002  ST ROSE HOSPITAL  27200 CALAROGA AVE  HAYWARD    CA
# 25762       50002  ST ROSE HOSPITAL  27200 CALAROGA AVE  HAYWARD    CA
# 25763       50002  ST ROSE HOSPITAL  27200 CALAROGA AVE  HAYWARD    CA
# 25764       50002  ST ROSE HOSPITAL  27200 CALAROGA AVE  HAYWARD    CA
# 25765       50002  ST ROSE HOSPITAL  27200 CALAROGA AVE  HAYWARD    CA
#
#        ZIP Code County Name    Phone Number      HCAHPS Measure ID  \
# 25761     94545     ALAMEDA  (510) 782-6200           H_COMP_1_A_P
# 25762     94545     ALAMEDA  (510) 782-6200          H_COMP_1_SN_P
# 25763     94545     ALAMEDA  (510) 782-6200           H_COMP_1_U_P
# 25764     94545     ALAMEDA  (510) 782-6200  H_COMP_1_LINEAR_SCORE
# 25765     94545     ALAMEDA  (510) 782-6200   H_COMP_1_STAR_RATING
#
#                                          HCAHPS Question  ...  \
# 25761  Patients who reported that their nurses "Alway...  ...
# ...

# %%
# filtering just the linear mean value
df=hcahps_ca[hcahps_ca['HCAHPS Linear Mean Value'].astype(str).str.isdigit()]
df
# Out:
#       Facility ID              Facility Name                Address  \
# 25764       50002           ST ROSE HOSPITAL     27200 CALAROGA AVE
# 25778       50002           ST ROSE HOSPITAL     27200 CALAROGA AVE
# 25792       50002           ST ROSE HOSPITAL     27200 CALAROGA AVE
# 25803       50002           ST ROSE HOSPITAL     27200 CALAROGA AVE
# 25813       50002           ST ROSE HOSPITAL     27200 CALAROGA AVE
# ...           ...                        ...                    ...
# 56047       51332  MARK TWAIN MEDICAL CENTER  768 MOUNTAIN RANCH RD
# 56061       51332  MARK TWAIN MEDICAL CENTER  768 MOUNTAIN RANCH RD
# 56066       51332  MARK TWAIN MEDICAL CENTER  768 MOUNTAIN RANCH RD
# 56071       51332  MARK TWAIN MEDICAL CENTER  768 MOUNTAIN RANCH RD
# 56076       51332  MARK TWAIN MEDICAL CENTER  768 MOUNTAIN RANCH RD
#
#               City State  ZIP Code County Name    Phone Number  \
# 25764      HAYWARD    CA     94545     ALAMEDA  (510) 782-6200
# ...

# %%
# clean
df_clean=df.astype({"Facility Name":"category","HCAHPS Question":"category","HCAHPS Linear Mean Value":int})
# df_clean
df_gp=df_clean.groupby(["HCAHPS Question","Facility Name"]).describe()
df_gp
# Out:
#                                                                                             ZIP Code  \
#                                                                                                count
# HCAHPS Question                          Facility Name
# Care transition - linear mean score      60th Medical Group (Travis AFB)                         1.0
#                                          ADVENTIST HEALTH AND RIDEOUT                            1.0
#                                          ADVENTIST HEALTH BAKERSFIELD                            1.0
#                                          ADVENTIST HEALTH CLEARLAKE                              1.0
#                                          ADVENTIST HEALTH DELANO                                 1.0
# ...                                                                                              ...
# Staff responsiveness - linear mean score WEST HILLS HOSPITAL & MEDICAL CENTER                    1.0
# ...
